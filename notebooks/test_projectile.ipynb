# %%
import os

# %%
cd llm-physics-discovery/
# Out:
# /mmfs1/home/oreoluwa.alade/llm-physics-discovery

# %%
from src.simulate import projectile
import matplotlib.pyplot as plt

# %%
t, y, meta = projectile(v0 = 20.0, theta_deg = 45.0, g = 9.81, noise = 0.05, num_points = 200,  seed  = 123)

# %%
# plot
plt.scatter(t, y, s=8, label="noisy data")
plt.title("Projectile Motion (with noise)")
plt.xlabel("time (s) ")
plt.ylabel("height (m)")
plt.legend()
plt.savefig("../llm-physics-discovery/figs/projectile.png") 
plt.show()
